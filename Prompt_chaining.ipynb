# %%
from langgraph.graph import StateGraph,START, END
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.2-3B-Instruct",
    task="text-generation",
)
model = ChatHuggingFace(llm=llm)

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str

# %%
def create_outline(state:BlogState)-> BlogState:

    #fetch title
    title = state['title']

    #call llm generate outline
    prompt = f"Create a detailed outline for a blog post titled '{title}'"

    outline = model.invoke(prompt).content

    #update state
    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState) -> BlogState:

    #fetch outline and title
    title = state['title']
    outline = state['outline']

    #call llm to generate blog content
    prompt = f"Write a detailed blog post based on the following title - '{title}' and strictly use the following outline - {outline}"

    content = model.invoke(prompt).content

    #update state
    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node("Create_outline",create_outline)
graph.add_node("Create_blog",create_blog)

graph.add_edge(START,"Create_outline")
graph.add_edge("Create_outline","Create_blog")
graph.add_edge("Create_blog",END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI'}

finally_state = workflow.invoke(initial_state)

print(finally_state)
# Out:
# {'title': 'Rise of AI', 'outline': 'Here\'s a detailed outline for the blog post "Rise of AI":\n\n**I. Introduction**\n\n* Brief overview of the AI revolution\n* Importance of understanding the AI trend\n* Thesis statement: The rise of AI is transforming industries and changing the world.\n\n**II. What is AI?**\n\n* Definition of Artificial Intelligence (AI)\n* Types of AI: Narrow AI, General AI, Superintelligence, and others\n* Current state of AI: Applications, limitations, and challenges\n\n**III. The History of AI**\n\n* Early beginnings of AI (1950s-1960s)\n* Development of expert systems and rule-based systems\n* Advances in machine learning (1970s-1980s)\n* The rise of deep learning (1990s-2000s)\n* Current developments in AI research\n\n**IV. AI in Various Industries**\n\n* **Healthcare:** AI-assisted diagnosis, personalized medicine, and medical research\n* **Finance:** AI-driven investment decisions, risk management, and customer service\n* **Retail:** AI-powered recommendation systems, inventory management, and supply chain optimization\n* **Transportation:** Autonomous vehicles, route optimization, and traffic management\n* **Education:** AI-driven learning platforms, personalized education, and grading systems\n\n**V. The Impact of AI on Society**\n\n* **Job displacement:** Will AI replace jobs or create new ones?\n* **Bias and fairness:** Ensuring AI systems are fair and unbiased\n* **Privacy concerns:** Protecting personal data in an AI-driven world\n* **Ethics and governance:** Regulating AI development and deployment\n\n**VI. The Future of AI**\n\n* **Advancements in AI:** Expected breakthroughs in areas like natural language processing, computer vision, and robotics\n* **Potential applications:** AI in space exploration, environmental monitoring, and social services\n* **Challenges and risks:** Mitigating the risks of AI, such as job displacement and bias\n\n**VII. Conclusion**\n\n* Recap of the rise of AI and its impact on society\n* Future predictions for AI development and deployment\n* Call to action: Embracing the opportunities and challenges of the AI revolution.\n\n**VIII. References**\n\n* List of sources used in the blog post.', 'content': '**The Rise of AI: Transforming Industries and Changing the World**\n\nThe world is on the cusp of an unprecedented revolution - the rise of Artificial Intelligence (AI). This technological marvel is transforming industries, changing the way we live and work, and opening up new opportunities for humanity. As AI continues to advance at an exponential rate, it\'s essential to understand its implications, both positive and negative. In this blog post, we\'ll delve into the history of AI, its current state, and its impact on various industries, as well as explore the challenges and risks associated with its development.\n\n**What is AI?**\n\nArtificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI can be categorized into several types, including:\n\n1. **Narrow AI**: Also known as "weak AI," narrow AI refers to AI systems that are designed to perform a specific task, such as image recognition, natural language processing, or gameplay.\n2. **General AI**: General AI refers to AI systems that possess human-like intelligence, capable of reasoning, problem-solving, and learning across a wide range of tasks.\n3. **Superintelligence**: Superintelligence refers to AI systems that are significantly more intelligent than the best human minds, potentially leading to exponential growth in technological advancement.\n4. **Hybrid AI**: Hybrid AI combines the strengths of narrow AI and general AI, enabling systems to learn and adapt in complex environments.\n\n**The History of AI**\n\nThe concept of AI dates back to the 1950s, when computer scientists like Alan Turing, Marvin Minsky, and John McCarthy began exploring the possibility of creati ...

# %%
print(finally_state['content'])
# Out:
# **The Rise of AI: Transforming Industries and Changing the World**
#
# The world is on the cusp of an unprecedented revolution - the rise of Artificial Intelligence (AI). This technological marvel is transforming industries, changing the way we live and work, and opening up new opportunities for humanity. As AI continues to advance at an exponential rate, it's essential to understand its implications, both positive and negative. In this blog post, we'll delve into the history of AI, its current state, and its impact on various industries, as well as explore the challenges and risks associated with its development.
#
# **What is AI?**
#
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI can be categorized into several types, including:
#
# 1. **Narrow AI**: Also known as "weak AI," narrow AI refers to AI systems that are designed to perform a specific task, such as image recognition, natural language processing, or gameplay.
# 2. **General AI**: General AI refers to AI systems that possess human-like intelligence, capable of reasoning, problem-solving, and learning across a wide range of tasks.
# 3. **Superintelligence**: Superintelligence refers to AI systems that are significantly more intelligent than the best human minds, potentially leading to exponential growth in technological advancement.
# 4. **Hybrid AI**: Hybrid AI combines the strengths of narrow AI and general AI, enabling systems to learn and adapt in complex environments.
#
# **The History of AI**
#
# The concept of AI dates back to the 1950s, when computer scientists like Alan Turing, Marvin Minsky, and John McCarthy began exploring the possibility of creating intelligent machines. The development of expert systems and rule-based systems in the 1960s and 1970s marked the beginning of AI research. The 1980s saw the emergence of machine learning, which enabled AI systems to learn from data and improve their performance over time.
#
# In the 1990s and 2000s, the rise of deep learning revolutionized the field of AI, enabling systems to learn complex patterns and relationships in data. Today, AI research is focused on developing more sophisticated AI systems that can learn, adapt, and interact with humans in natural language, speech, vision, and other modalities.
#
# **AI in Various Industries**
#
# **Healthcare:**
#
# AI-assisted diagnosis and personalized medicine are transforming the healthcare industry. AI-powered systems can analyze medical images, diagnose diseases, and develop personalized treatment plans. Furthermore

# %%
print(finally_state['outline'])
# Out:
# Here's a detailed outline for the blog post "Rise of AI":
#
# **I. Introduction**
#
# * Brief overview of the AI revolution
# * Importance of understanding the AI trend
# * Thesis statement: The rise of AI is transforming industries and changing the world.
#
# **II. What is AI?**
#
# * Definition of Artificial Intelligence (AI)
# * Types of AI: Narrow AI, General AI, Superintelligence, and others
# * Current state of AI: Applications, limitations, and challenges
#
# **III. The History of AI**
#
# * Early beginnings of AI (1950s-1960s)
# * Development of expert systems and rule-based systems
# * Advances in machine learning (1970s-1980s)
# * The rise of deep learning (1990s-2000s)
# * Current developments in AI research
#
# **IV. AI in Various Industries**
#
# * **Healthcare:** AI-assisted diagnosis, personalized medicine, and medical research
# * **Finance:** AI-driven investment decisions, risk management, and customer service
# * **Retail:** AI-powered recommendation systems, inventory management, and supply chain optimization
# * **Transportation:** Autonomous vehicles, route optimization, and traffic management
# * **Education:** AI-driven learning platforms, personalized education, and grading systems
#
# **V. The Impact of AI on Society**
#
# * **Job displacement:** Will AI replace jobs or create new ones?
# * **Bias and fairness:** Ensuring AI systems are fair and unbiased
# * **Privacy concerns:** Protecting personal data in an AI-driven world
# * **Ethics and governance:** Regulating AI development and deployment
#
# **VI. The Future of AI**
#
# * **Advancements in AI:** Expected breakthroughs in areas like natural language processing, computer vision, and robotics
# * **Potential applications:** AI in space exploration, environmental monitoring, and social services
# * **Challenges and risks:** Mitigating the risks of AI, such as job displacement and bias
#
# **VII. Conclusion**
#
# * Recap of the rise of AI and its impact on society
# * Future predictions for AI development and deployment
# * Call to action: Embracing the opportunities and challenges of the AI revolution.
#
# **VIII. References**
#
# * List of sources used in the blog post.
