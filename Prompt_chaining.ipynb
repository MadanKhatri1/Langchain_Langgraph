# %%
from langgraph.graph import StateGraph,START, END
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.2-3B-Instruct",
    task="text-generation",
)
model = ChatHuggingFace(llm=llm)

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str
    rate: int

# %%
def create_outline(state:BlogState)-> BlogState:

    #fetch title
    title = state['title']

    #call llm generate outline
    prompt = f"Create a detailed outline for a blog post titled '{title}'"

    outline = model.invoke(prompt).content

    #update state
    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState) -> BlogState:

    #fetch outline and title
    title = state['title']
    outline = state['outline']

    #call llm to generate blog content
    prompt = f"Write a detailed blog post based on the following title - '{title}' and strictly use the following outline - {outline}"

    content = model.invoke(prompt).content

    #update state
    state['content'] = content

    return state

# %%
def rate_blog(state: BlogState) -> BlogState:

    #fetch content
    content = state['content']

    #call llm 
    prompt = f"Rate the following blog content on a scale of 1 to 10 for its quality, coherence, and engagement: {content} Provide only the rating number."

    rating = model.invoke(prompt).content

    state['rate'] = int(rating)

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node("Create_outline",create_outline)
graph.add_node("Create_blog",create_blog)
graph.add_node("rate_blog",rate_blog)

graph.add_edge(START,"Create_outline")
graph.add_edge("Create_outline","Create_blog")
graph.add_edge("Create_blog","rate_blog")
graph.add_edge("rate_blog",END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI'}

finally_state = workflow.invoke(initial_state)

print(finally_state)
# Out:
# {'title': 'Rise of AI', 'outline': 'Here\'s a detailed outline for a blog post titled \'The Rise of AI\':\n\n**I. Introduction**\n\n* Briefly introduce the concept of Artificial Intelligence (AI) and its increasing presence in our daily lives\n* Explain the purpose of the blog post: to explore the current state of AI, its potential benefits, and its implications on society\n* Provide a thesis statement, such as: "The rise of AI is transforming the world in unprecedented ways, presenting both opportunities and challenges that require careful consideration and planning."\n\n**II. Current State of AI**\n\n* Define AI and its types (narrow, general, and superintelligence)\n* Discuss the latest advancements in AI, including:\n + Machine learning and deep learning\n + Natural Language Processing (NLP)\n + Computer Vision\n + Robotics\n* Highlight notable AI achievements, such as:\n + Image recognition\n + Speech recognition\n + Self-driving cars\n + Personalized medicine\n\n**III. Benefits of AI**\n\n* Discuss the benefits of AI, such as:\n + Improved efficiency and productivity\n + Enhanced decision-making\n + Personalized experiences\n + Improved healthcare outcomes\n + Environmental sustainability\n* Provide examples of AI applications in various industries, such as:\n + Healthcare: disease diagnosis, personalized medicine\n + Education: adaptive learning, intelligent tutoring systems\n + Finance: algorithmic trading, risk management\n + Transportation: self-driving cars, autonomous trucks\n\n**IV. Potential Risks and Challenges**\n\n* Discuss the potential risks and challenges associated with AI, such as:\n + Job displacement\n + Bias and fairness\n + Cybersecurity threats\n + Existential risks (e.g., superintelligence)\n* Highlight the need for:\n + AI governance and regulation\n + Data privacy and security\n + Public awareness and education\n + Research and development of AI safety protocols\n\n**V. The Future of AI**\n\n* Discuss the potential future developments in AI, such as:\n + Edge AI and IoT applications\n + Quantum AI and machine learning\n + Human-AI collaboration\n + Ethics and responsibility in AI development\n* Highlight the importance of addressing the challenges and risks associated with AI, and the need for a coordinated global effort to ensure a safe and beneficial future for AI.\n\n**VI. Conclusion**\n\n* Summarize the key points discussed in the blog post\n* Emphasize the importance of considering the broader implications of AI on society\n* Encourage readers to engage with the topic and contribute to the ongoing conversation about the rise of AI.\n\n**VII. References**\n\n* List relevant sources and studies used in the blog', 'content': '**The Rise of AI: Transformation and Challenges in the Digital Age**\n\nThe world is witnessing an unprecedented transformation with the rise of Artificial Intelligence (AI). This technology has been a cornerstone of science fiction for decades, but its rapid growth and advancements have made it a fundamental aspect of our daily lives. From personalized recommendations on our favorite streaming platforms to the self-driving cars that are revolutionizing the transportation industry, AI is surrounding us in ways both subtle and profound. In this blog post, we will delve into the current state of AI, its benefits, and the potential risks and challenges that it poses to society, as well as explore the future directions of this transformative technology.\n\n**I. Introduction**\n\nArtificial Intelligence (AI) has been an active area of research for several decades, but its recent growth has been nothing short of astonishing. AI systems are now capable of complex tasks that were previously thought to be the exclusive domain of humans, such as learning, reasoning, and problem-solving. The increasing presence of AI in our daily lives is a reflection of its vast potential to improve efficiency, productivity, and decision-making, while also presenting new challenges and concerns for s ...

# %%
print(finally_state['content'])
# Out:
# **The Rise of AI: Transformation and Challenges in the Digital Age**
#
# The world is witnessing an unprecedented transformation with the rise of Artificial Intelligence (AI). This technology has been a cornerstone of science fiction for decades, but its rapid growth and advancements have made it a fundamental aspect of our daily lives. From personalized recommendations on our favorite streaming platforms to the self-driving cars that are revolutionizing the transportation industry, AI is surrounding us in ways both subtle and profound. In this blog post, we will delve into the current state of AI, its benefits, and the potential risks and challenges that it poses to society, as well as explore the future directions of this transformative technology.
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has been an active area of research for several decades, but its recent growth has been nothing short of astonishing. AI systems are now capable of complex tasks that were previously thought to be the exclusive domain of humans, such as learning, reasoning, and problem-solving. The increasing presence of AI in our daily lives is a reflection of its vast potential to improve efficiency, productivity, and decision-making, while also presenting new challenges and concerns for society. The purpose of this blog post is to explore the current state of AI, its potential benefits, and its implications on society, arguing that "The rise of AI is transforming the world in unprecedented ways, presenting both opportunities and challenges that require careful consideration and planning."
#
# **II. Current State of AI**
#
# Artificial Intelligence encompasses a broad range of technologies and approaches, which can be broadly categorized into three types: narrow, general, and superintelligence. Narrow AI refers to the use of AI systems to perform specific tasks, such as image recognition, speech recognition, and natural language processing. General AI, on the other hand, refers to AI systems that can perform any intellectual task that humans can. Superintelligence is a hypothetical AI system that is significantly more intelligent than the best human minds.
#
# The latest advancements in AI are numerous and far-reaching. Machine learning and deep learning are two key technologies that have enabled AI systems to learn from data and improve their performance over time. Natural Language Processing (NLP) has made it possible for AI systems to understand and generate human language, while computer vision has enabled AI systems to interpret and understand visual data. Robotics has enabled the development of AI-powered robots that can perform complex tasks in various industries.
#
# Notable AI achievements include image recognition, speech recognition, self-driving cars, and personalized medicine. Image recognition has enabled AI systems to analyze and recognize images with unprecedented accuracy, leading

# %%
print(finally_state['outline'])
# Out:
# Here's a detailed outline for a blog post titled 'The Rise of AI':
#
# **I. Introduction**
#
# * Briefly introduce the concept of Artificial Intelligence (AI) and its increasing presence in our daily lives
# * Explain the purpose of the blog post: to explore the current state of AI, its potential benefits, and its implications on society
# * Provide a thesis statement, such as: "The rise of AI is transforming the world in unprecedented ways, presenting both opportunities and challenges that require careful consideration and planning."
#
# **II. Current State of AI**
#
# * Define AI and its types (narrow, general, and superintelligence)
# * Discuss the latest advancements in AI, including:
#  + Machine learning and deep learning
#  + Natural Language Processing (NLP)
#  + Computer Vision
#  + Robotics
# * Highlight notable AI achievements, such as:
#  + Image recognition
#  + Speech recognition
#  + Self-driving cars
#  + Personalized medicine
#
# **III. Benefits of AI**
#
# * Discuss the benefits of AI, such as:
#  + Improved efficiency and productivity
#  + Enhanced decision-making
#  + Personalized experiences
#  + Improved healthcare outcomes
#  + Environmental sustainability
# * Provide examples of AI applications in various industries, such as:
#  + Healthcare: disease diagnosis, personalized medicine
#  + Education: adaptive learning, intelligent tutoring systems
#  + Finance: algorithmic trading, risk management
#  + Transportation: self-driving cars, autonomous trucks
#
# **IV. Potential Risks and Challenges**
#
# * Discuss the potential risks and challenges associated with AI, such as:
#  + Job displacement
#  + Bias and fairness
#  + Cybersecurity threats
#  + Existential risks (e.g., superintelligence)
# * Highlight the need for:
#  + AI governance and regulation
#  + Data privacy and security
#  + Public awareness and education
#  + Research and development of AI safety protocols
#
# **V. The Future of AI**
#
# * Discuss the potential future developments in AI, such as:
#  + Edge AI and IoT applications
#  + Quantum AI and machine learning
#  + Human-AI collaboration
#  + Ethics and responsibility in AI development
# * Highlight the importance of addressing the challenges and risks associated with AI, and the need for a coordinated global effort to ensure a safe and beneficial future for AI.
#
# **VI. Conclusion**
#
# * Summarize the key points discussed in the blog post
# * Emphasize the importance of considering the broader implications of AI on society
# * Encourage readers to engage with the topic and contribute to the ongoing conversation about the rise of AI.
#
# **VII. References**
#
# * List relevant sources and studies used in the blog

# %%
print(finally_state['rate'])
# Out:
# 7
